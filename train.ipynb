# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !yolo task=detect mode=train model=yolov8l.pt data="C:/SFU Grad/Fall 2025/CMPT 742/Assignments/CMPT742-Final-Project---Pothole-Detection/Datasets/Pothole/data.yaml" epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.233  Python-3.12.2 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...
